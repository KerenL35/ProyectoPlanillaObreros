-- %% [markdown]
-- # [PlanillaObrera]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PlanillaObrera]    Script Date: 20/10/2023 8:39:50 p. m. ******/
CREATE DATABASE [PlanillaObrera]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PlanillaObrera', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\PlanillaObrera.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PlanillaObrera_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\PlanillaObrera_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [PlanillaObrera] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PlanillaObrera].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PlanillaObrera] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PlanillaObrera] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PlanillaObrera] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PlanillaObrera] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PlanillaObrera] SET ARITHABORT OFF 
GO
ALTER DATABASE [PlanillaObrera] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [PlanillaObrera] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PlanillaObrera] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PlanillaObrera] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PlanillaObrera] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PlanillaObrera] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PlanillaObrera] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PlanillaObrera] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PlanillaObrera] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PlanillaObrera] SET  DISABLE_BROKER 
GO
ALTER DATABASE [PlanillaObrera] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PlanillaObrera] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PlanillaObrera] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PlanillaObrera] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PlanillaObrera] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PlanillaObrera] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PlanillaObrera] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PlanillaObrera] SET RECOVERY FULL 
GO
ALTER DATABASE [PlanillaObrera] SET  MULTI_USER 
GO
ALTER DATABASE [PlanillaObrera] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PlanillaObrera] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PlanillaObrera] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PlanillaObrera] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PlanillaObrera] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PlanillaObrera] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'PlanillaObrera', N'ON'
GO
ALTER DATABASE [PlanillaObrera] SET QUERY_STORE = ON
GO
ALTER DATABASE [PlanillaObrera] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[DBErrors]

-- %%
USE [PlanillaObrera]
GO

-- %%
/****** Object:  Table [dbo].[DBErrors]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DBErrors](
	[ERROR] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](100) NULL,
	[ErrorNumber] [int] NULL,
	[ErrorState] [int] NULL,
	[ErrorSeverity] [int] NULL,
	[ErrorLine] [int] NULL,
	[ErrorProcedure] [varchar](max) NULL,
	[ErrorMessage] [varchar](max) NULL,
	[ErrorDateTime] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeduccionXempleado]

-- %%
/****** Object:  Table [dbo].[DeduccionXempleado]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeduccionXempleado](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tipoDeducId] [int] NOT NULL,
	[empleadoId] [int] NOT NULL,
	[fijoNoObligatorioId] [int] NOT NULL,
 CONSTRAINT [PK_DeduccionXempleado] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeducPorcentualObligatoria]

-- %%
/****** Object:  Table [dbo].[DeducPorcentualObligatoria]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeducPorcentualObligatoria](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[porcentaje] [float] NOT NULL,
 CONSTRAINT [PK_DeducPorcentualObligatoria] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeducXEmpXMes]

-- %%
/****** Object:  Table [dbo].[DeducXEmpXMes]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeducXEmpXMes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[totalDeducciones] [int] NOT NULL,
	[tipoDeduccionId] [int] NOT NULL,
 CONSTRAINT [PK_DeducXEmpXMes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Departamento]

-- %%
/****** Object:  Table [dbo].[Departamento]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Departamento](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
 CONSTRAINT [PK_Departamento] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empleado]

-- %%
/****** Object:  Table [dbo].[Empleado]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleado](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[valorDocid] [int] NOT NULL,
	[fechaNacimiento] [date] NULL,
	[puestoId] [int] NOT NULL,
	[departamentoId] [int] NOT NULL,
	[jornadaId] [int] NOT NULL,
	[PlanillaSemXEmpId] [int] NOT NULL,
 CONSTRAINT [PK_Empleado] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EventLog]

-- %%
/****** Object:  Table [dbo].[EventLog]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EventLog](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[LogDescription] [varchar](2000) NOT NULL,
	[PosIdUser] [int] NOT NULL,
	[PosIP] [varchar](64) NOT NULL,
	[PostTime] [datetime] NOT NULL,
 CONSTRAINT [PK_EventLog] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Feriado]

-- %%
/****** Object:  Table [dbo].[Feriado]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Feriado](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[fecha] [date] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FijaNoObligatoria]

-- %%
/****** Object:  Table [dbo].[FijaNoObligatoria]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FijaNoObligatoria](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[monto] [int] NOT NULL,
 CONSTRAINT [PK_FijaNoObligatoria] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jornada]

-- %%
/****** Object:  Table [dbo].[Jornada]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jornada](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[MarcaAsistenciaId] [int] NOT NULL,
	[tipoJornadaId] [int] NOT NULL,
	[SemanaPlanillaId] [int] NOT NULL,
 CONSTRAINT [PK_Jornada] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MarcasAsistencia]

-- %%
/****** Object:  Table [dbo].[MarcasAsistencia]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MarcasAsistencia](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[marcaInicio] [datetime] NOT NULL,
	[marcaFinal] [datetime] NOT NULL,
 CONSTRAINT [PK_Marcas] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MesPlanilla]

-- %%
/****** Object:  Table [dbo].[MesPlanilla]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MesPlanilla](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fechaInicio] [datetime] NOT NULL,
	[fechaFin] [datetime] NOT NULL,
	[semanaPlanillaId] [int] NOT NULL,
 CONSTRAINT [PK_MesPlanilla] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MovDeduccion]

-- %%
/****** Object:  Table [dbo].[MovDeduccion]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MovDeduccion](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[DeduccionXempleadoId] [int] NOT NULL,
 CONSTRAINT [PK_MovDeduccion] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MovHoras]

-- %%
/****** Object:  Table [dbo].[MovHoras]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MovHoras](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[marcasAsistenciaId] [int] NOT NULL,
 CONSTRAINT [PK_MovHoras] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MovimientoPlanilla]

-- %%
/****** Object:  Table [dbo].[MovimientoPlanilla]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MovimientoPlanilla](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [datetime] NOT NULL,
	[monto] [money] NOT NULL,
	[nuevoSalarioBruto] [money] NOT NULL,
	[tipoMovPlanillaId] [int] NOT NULL,
	[movHorasId] [int] NOT NULL,
	[movDeduccionId] [int] NOT NULL,
 CONSTRAINT [PK_MovimientoPlanilla] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlanillaMesXEmp]

-- %%
/****** Object:  Table [dbo].[PlanillaMesXEmp]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlanillaMesXEmp](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[salarioBruto] [money] NOT NULL,
	[totalDeducciones] [money] NOT NULL,
	[mesPlanillaId] [int] NOT NULL,
	[DeduccionXempXmesId] [int] NOT NULL,
 CONSTRAINT [PK_PlanillaMesXEmp] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlanillaSemXEmp]

-- %%
/****** Object:  Table [dbo].[PlanillaSemXEmp]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlanillaSemXEmp](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[salarioNeto] [money] NOT NULL,
	[movPlanillaId] [int] NOT NULL,
	[semanaPlanillaId] [int] NOT NULL,
	[planillaMesXempId] [int] NOT NULL,
	[salarioBruto] [money] NOT NULL,
	[totalDeducciones] [money] NOT NULL,
 CONSTRAINT [PK_PlanillaSemXEmp] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Puesto]

-- %%
/****** Object:  Table [dbo].[Puesto]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Puesto](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[salarioXhora] [money] NOT NULL,
 CONSTRAINT [PK_Puesto] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SemanaPlanilla]

-- %%
/****** Object:  Table [dbo].[SemanaPlanilla]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SemanaPlanilla](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fechaInicio] [datetime] NOT NULL,
	[fechaFin] [datetime] NOT NULL,
 CONSTRAINT [PK_SemanaPlanilla] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoDeduccion]

-- %%
/****** Object:  Table [dbo].[TipoDeduccion]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoDeduccion](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[esObligatoria] [bit] NOT NULL,
	[esPorcentual] [bit] NOT NULL,
	[DeducPorcentualObligatoriaId] [int] NOT NULL,
 CONSTRAINT [PK_TipoDeduccion] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoDocIdentidad]

-- %%
/****** Object:  Table [dbo].[TipoDocIdentidad]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoDocIdentidad](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
 CONSTRAINT [PK_TipoDocIdentidad] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoJornada]

-- %%
/****** Object:  Table [dbo].[TipoJornada]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoJornada](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[fechaInicio] [datetime] NOT NULL,
	[fechaFin] [datetime] NOT NULL,
 CONSTRAINT [PK_TipoJornada] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoMovDeduccion]

-- %%
/****** Object:  Table [dbo].[TipoMovDeduccion]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoMovDeduccion](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[tipoDeduccionId] [int] NOT NULL,
 CONSTRAINT [PK_TipoMovDeduccion] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoMovimientoPlanilla]

-- %%
/****** Object:  Table [dbo].[TipoMovimientoPlanilla]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoMovimientoPlanilla](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[tipoMovDeduccionId] [int] NOT NULL,
 CONSTRAINT [PK_TipoMovimientoPlanilla] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[clave] [varchar](64) NOT NULL,
	[tipo] [varchar](64) NOT NULL,
	[nombre] [varchar](64) NOT NULL,
	[empleadoId] [int] NOT NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_DeduccionXempleado_Empleado_empleadoId]

-- %%
ALTER TABLE [dbo].[DeduccionXempleado]  WITH CHECK ADD  CONSTRAINT [FK_DeduccionXempleado_Empleado_empleadoId] FOREIGN KEY([empleadoId])
REFERENCES [dbo].[Empleado] ([id])
GO
ALTER TABLE [dbo].[DeduccionXempleado] CHECK CONSTRAINT [FK_DeduccionXempleado_Empleado_empleadoId]
GO

-- %% [markdown]
-- # [FK_DeduccionXempleado_FijaNoObligatoria_fijoNoObligatorioId]

-- %%
ALTER TABLE [dbo].[DeduccionXempleado]  WITH CHECK ADD  CONSTRAINT [FK_DeduccionXempleado_FijaNoObligatoria_fijoNoObligatorioId] FOREIGN KEY([fijoNoObligatorioId])
REFERENCES [dbo].[FijaNoObligatoria] ([id])
GO
ALTER TABLE [dbo].[DeduccionXempleado] CHECK CONSTRAINT [FK_DeduccionXempleado_FijaNoObligatoria_fijoNoObligatorioId]
GO

-- %% [markdown]
-- # [FK_DeduccionXempleado_TipoDeduccion_tipoDeducId]

-- %%
ALTER TABLE [dbo].[DeduccionXempleado]  WITH CHECK ADD  CONSTRAINT [FK_DeduccionXempleado_TipoDeduccion_tipoDeducId] FOREIGN KEY([tipoDeducId])
REFERENCES [dbo].[TipoDeduccion] ([id])
GO
ALTER TABLE [dbo].[DeduccionXempleado] CHECK CONSTRAINT [FK_DeduccionXempleado_TipoDeduccion_tipoDeducId]
GO

-- %% [markdown]
-- # [FK_DeducXEmpXMes_TipoDeduccion_tipoDeduccionId]

-- %%
ALTER TABLE [dbo].[DeducXEmpXMes]  WITH CHECK ADD  CONSTRAINT [FK_DeducXEmpXMes_TipoDeduccion_tipoDeduccionId] FOREIGN KEY([tipoDeduccionId])
REFERENCES [dbo].[TipoDeduccion] ([id])
GO
ALTER TABLE [dbo].[DeducXEmpXMes] CHECK CONSTRAINT [FK_DeducXEmpXMes_TipoDeduccion_tipoDeduccionId]
GO

-- %% [markdown]
-- # [FK_Empleado_Departamento_departamentoId]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [FK_Empleado_Departamento_departamentoId] FOREIGN KEY([departamentoId])
REFERENCES [dbo].[Departamento] ([id])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_Departamento_departamentoId]
GO

-- %% [markdown]
-- # [FK_Empleado_Jornada_jornadaId]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [FK_Empleado_Jornada_jornadaId] FOREIGN KEY([jornadaId])
REFERENCES [dbo].[Jornada] ([id])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_Jornada_jornadaId]
GO

-- %% [markdown]
-- # [FK_Empleado_PlanillaSemXEmp_PlanillaSemXEmpId]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [FK_Empleado_PlanillaSemXEmp_PlanillaSemXEmpId] FOREIGN KEY([PlanillaSemXEmpId])
REFERENCES [dbo].[PlanillaSemXEmp] ([id])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_PlanillaSemXEmp_PlanillaSemXEmpId]
GO

-- %% [markdown]
-- # [FK_Empleado_Puesto_puestoId]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [FK_Empleado_Puesto_puestoId] FOREIGN KEY([puestoId])
REFERENCES [dbo].[Puesto] ([id])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_Puesto_puestoId]
GO

-- %% [markdown]
-- # [FK_Empleado_TipoDocIdentidad_valorDocid]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [FK_Empleado_TipoDocIdentidad_valorDocid] FOREIGN KEY([valorDocid])
REFERENCES [dbo].[TipoDocIdentidad] ([id])
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [FK_Empleado_TipoDocIdentidad_valorDocid]
GO

-- %% [markdown]
-- # [FK_Jornada_MarcasAsistencia_MarcaAsistenciaId]

-- %%
ALTER TABLE [dbo].[Jornada]  WITH CHECK ADD  CONSTRAINT [FK_Jornada_MarcasAsistencia_MarcaAsistenciaId] FOREIGN KEY([MarcaAsistenciaId])
REFERENCES [dbo].[MarcasAsistencia] ([id])
GO
ALTER TABLE [dbo].[Jornada] CHECK CONSTRAINT [FK_Jornada_MarcasAsistencia_MarcaAsistenciaId]
GO

-- %% [markdown]
-- # [FK_Jornada_SemanaPlanilla_SemanaPlanillaId]

-- %%
ALTER TABLE [dbo].[Jornada]  WITH CHECK ADD  CONSTRAINT [FK_Jornada_SemanaPlanilla_SemanaPlanillaId] FOREIGN KEY([SemanaPlanillaId])
REFERENCES [dbo].[SemanaPlanilla] ([id])
GO
ALTER TABLE [dbo].[Jornada] CHECK CONSTRAINT [FK_Jornada_SemanaPlanilla_SemanaPlanillaId]
GO

-- %% [markdown]
-- # [FK_Jornada_TipoJornada_tipoJornadaId]

-- %%
ALTER TABLE [dbo].[Jornada]  WITH CHECK ADD  CONSTRAINT [FK_Jornada_TipoJornada_tipoJornadaId] FOREIGN KEY([tipoJornadaId])
REFERENCES [dbo].[TipoJornada] ([id])
GO
ALTER TABLE [dbo].[Jornada] CHECK CONSTRAINT [FK_Jornada_TipoJornada_tipoJornadaId]
GO

-- %% [markdown]
-- # [FK_MesPlanilla_SemanaPlanilla_semanaPlanillaId]

-- %%
ALTER TABLE [dbo].[MesPlanilla]  WITH CHECK ADD  CONSTRAINT [FK_MesPlanilla_SemanaPlanilla_semanaPlanillaId] FOREIGN KEY([semanaPlanillaId])
REFERENCES [dbo].[SemanaPlanilla] ([id])
GO
ALTER TABLE [dbo].[MesPlanilla] CHECK CONSTRAINT [FK_MesPlanilla_SemanaPlanilla_semanaPlanillaId]
GO

-- %% [markdown]
-- # [FK_MovDeduccion_DeduccionXempleado_DeduccionXempleadoId]

-- %%
ALTER TABLE [dbo].[MovDeduccion]  WITH CHECK ADD  CONSTRAINT [FK_MovDeduccion_DeduccionXempleado_DeduccionXempleadoId] FOREIGN KEY([DeduccionXempleadoId])
REFERENCES [dbo].[DeduccionXempleado] ([id])
GO
ALTER TABLE [dbo].[MovDeduccion] CHECK CONSTRAINT [FK_MovDeduccion_DeduccionXempleado_DeduccionXempleadoId]
GO

-- %% [markdown]
-- # [FK_MovHoras_MarcasAsistencia-marcasAsistenciaId]

-- %%
ALTER TABLE [dbo].[MovHoras]  WITH CHECK ADD  CONSTRAINT [FK_MovHoras_MarcasAsistencia-marcasAsistenciaId] FOREIGN KEY([marcasAsistenciaId])
REFERENCES [dbo].[MarcasAsistencia] ([id])
GO
ALTER TABLE [dbo].[MovHoras] CHECK CONSTRAINT [FK_MovHoras_MarcasAsistencia-marcasAsistenciaId]
GO

-- %% [markdown]
-- # [FK_MovimientoPlanilla_MovDeduccion_movDeduccionId]

-- %%
ALTER TABLE [dbo].[MovimientoPlanilla]  WITH CHECK ADD  CONSTRAINT [FK_MovimientoPlanilla_MovDeduccion_movDeduccionId] FOREIGN KEY([movDeduccionId])
REFERENCES [dbo].[MovDeduccion] ([id])
GO
ALTER TABLE [dbo].[MovimientoPlanilla] CHECK CONSTRAINT [FK_MovimientoPlanilla_MovDeduccion_movDeduccionId]
GO

-- %% [markdown]
-- # [FK_MovimientoPlanilla_MovHoras_movHorasId]

-- %%
ALTER TABLE [dbo].[MovimientoPlanilla]  WITH CHECK ADD  CONSTRAINT [FK_MovimientoPlanilla_MovHoras_movHorasId] FOREIGN KEY([movHorasId])
REFERENCES [dbo].[MovHoras] ([id])
GO
ALTER TABLE [dbo].[MovimientoPlanilla] CHECK CONSTRAINT [FK_MovimientoPlanilla_MovHoras_movHorasId]
GO

-- %% [markdown]
-- # [FK_MovimientoPlanilla_TipoMovimientoPlanilla_tipoMovPlanillaId]

-- %%
ALTER TABLE [dbo].[MovimientoPlanilla]  WITH CHECK ADD  CONSTRAINT [FK_MovimientoPlanilla_TipoMovimientoPlanilla_tipoMovPlanillaId] FOREIGN KEY([tipoMovPlanillaId])
REFERENCES [dbo].[TipoMovimientoPlanilla] ([id])
GO
ALTER TABLE [dbo].[MovimientoPlanilla] CHECK CONSTRAINT [FK_MovimientoPlanilla_TipoMovimientoPlanilla_tipoMovPlanillaId]
GO

-- %% [markdown]
-- # [FK_PlanillaMesXEmp_DeducXEmpXMes_DeduccionXempXmesId]

-- %%
ALTER TABLE [dbo].[PlanillaMesXEmp]  WITH CHECK ADD  CONSTRAINT [FK_PlanillaMesXEmp_DeducXEmpXMes_DeduccionXempXmesId] FOREIGN KEY([DeduccionXempXmesId])
REFERENCES [dbo].[DeducXEmpXMes] ([id])
GO
ALTER TABLE [dbo].[PlanillaMesXEmp] CHECK CONSTRAINT [FK_PlanillaMesXEmp_DeducXEmpXMes_DeduccionXempXmesId]
GO

-- %% [markdown]
-- # [FK_PlanillaMesXEmp_MesPlanilla_mesPlanillaId]

-- %%
ALTER TABLE [dbo].[PlanillaMesXEmp]  WITH CHECK ADD  CONSTRAINT [FK_PlanillaMesXEmp_MesPlanilla_mesPlanillaId] FOREIGN KEY([mesPlanillaId])
REFERENCES [dbo].[MesPlanilla] ([id])
GO
ALTER TABLE [dbo].[PlanillaMesXEmp] CHECK CONSTRAINT [FK_PlanillaMesXEmp_MesPlanilla_mesPlanillaId]
GO

-- %% [markdown]
-- # [FK_PlanillaSemXEmp_MovimientoPlanilla_movPlanillaId]

-- %%
ALTER TABLE [dbo].[PlanillaSemXEmp]  WITH CHECK ADD  CONSTRAINT [FK_PlanillaSemXEmp_MovimientoPlanilla_movPlanillaId] FOREIGN KEY([movPlanillaId])
REFERENCES [dbo].[MovimientoPlanilla] ([id])
GO
ALTER TABLE [dbo].[PlanillaSemXEmp] CHECK CONSTRAINT [FK_PlanillaSemXEmp_MovimientoPlanilla_movPlanillaId]
GO

-- %% [markdown]
-- # [FK_PlanillaSemXEmp_PlanillaMesXEmp_planillaMesXempId]

-- %%
ALTER TABLE [dbo].[PlanillaSemXEmp]  WITH CHECK ADD  CONSTRAINT [FK_PlanillaSemXEmp_PlanillaMesXEmp_planillaMesXempId] FOREIGN KEY([planillaMesXempId])
REFERENCES [dbo].[PlanillaMesXEmp] ([id])
GO
ALTER TABLE [dbo].[PlanillaSemXEmp] CHECK CONSTRAINT [FK_PlanillaSemXEmp_PlanillaMesXEmp_planillaMesXempId]
GO

-- %% [markdown]
-- # [FK_PlanillaSemXEmp_SemanaPlanilla_semanaPlanillaId]

-- %%
ALTER TABLE [dbo].[PlanillaSemXEmp]  WITH CHECK ADD  CONSTRAINT [FK_PlanillaSemXEmp_SemanaPlanilla_semanaPlanillaId] FOREIGN KEY([semanaPlanillaId])
REFERENCES [dbo].[SemanaPlanilla] ([id])
GO
ALTER TABLE [dbo].[PlanillaSemXEmp] CHECK CONSTRAINT [FK_PlanillaSemXEmp_SemanaPlanilla_semanaPlanillaId]
GO

-- %% [markdown]
-- # [FK_TipoDeduccion_DeducPorcentualObligatoria_DeducPorcentualObligatoriaId]

-- %%
ALTER TABLE [dbo].[TipoDeduccion]  WITH CHECK ADD  CONSTRAINT [FK_TipoDeduccion_DeducPorcentualObligatoria_DeducPorcentualObligatoriaId] FOREIGN KEY([DeducPorcentualObligatoriaId])
REFERENCES [dbo].[DeducPorcentualObligatoria] ([id])
GO
ALTER TABLE [dbo].[TipoDeduccion] CHECK CONSTRAINT [FK_TipoDeduccion_DeducPorcentualObligatoria_DeducPorcentualObligatoriaId]
GO

-- %% [markdown]
-- # [FK_TipoMovimientoPlanilla_TipoMovDeduccion_tipoMovDeduccionId]

-- %%
ALTER TABLE [dbo].[TipoMovimientoPlanilla]  WITH CHECK ADD  CONSTRAINT [FK_TipoMovimientoPlanilla_TipoMovDeduccion_tipoMovDeduccionId] FOREIGN KEY([tipoMovDeduccionId])
REFERENCES [dbo].[TipoMovDeduccion] ([id])
GO
ALTER TABLE [dbo].[TipoMovimientoPlanilla] CHECK CONSTRAINT [FK_TipoMovimientoPlanilla_TipoMovDeduccion_tipoMovDeduccionId]
GO

-- %% [markdown]
-- # [FK_Usuario_Empleado_empleadoId]

-- %%
ALTER TABLE [dbo].[Usuario]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Empleado_empleadoId] FOREIGN KEY([empleadoId])
REFERENCES [dbo].[Empleado] ([id])
GO
ALTER TABLE [dbo].[Usuario] CHECK CONSTRAINT [FK_Usuario_Empleado_empleadoId]
GO

-- %% [markdown]
-- # [dbo].[AcumularDeduccionesXEmpleadoxMes]

-- %%
/****** Object:  StoredProcedure [dbo].[AcumularDeduccionesXEmpleadoxMes]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- Crear el nuevo procedimiento almacenado
CREATE PROCEDURE [dbo].[AcumularDeduccionesXEmpleadoxMes]
    @outResultCode INT OUTPUT
AS
BEGIN
    -- SET NOCOUNT ON added to prevent extra result sets from interfering with SELECT statements.
    SET NOCOUNT ON;

    -- Inicializa el código de resultado a 0 (sin error)
    SET @outResultCode = 0;

    BEGIN TRY
        -- Crear una tabla temporal para almacenar los resultados
        CREATE TABLE #TempResult (
            EmpleadoId INT,
            TipoDeduccionId INT,
            MontoTotalDeducciones DECIMAL(10, 2)
        );

        -- Insertar los totales de deducciones por tipo de deducción y empleado en la tabla temporal
        INSERT INTO #TempResult (EmpleadoId, TipoDeduccionId, MontoTotalDeducciones)
        SELECT
            DE.EmpleadoId,
            DE.TipoDeduccionId,
            SUM(DE.MontoDeduccion)
        FROM [dbo].[DeduccionesEmpleado] AS DE
        WHERE
            DATEPART(MONTH, DE.Fecha) = DATEPART(MONTH, GETDATE())
        GROUP BY DE.EmpleadoId, DE.TipoDeduccionId;

        -- Actualizar la tabla DeduccionesXEmpleadoxMes con los totales acumulados
        UPDATE DXE
        SET DXE.MontoTotalDeducciones = ISNULL(
            TR.MontoTotalDeducciones, 0
        )
        FROM [dbo].[DeduccionesXEmpleadoxMes] AS DXE
        LEFT JOIN #TempResult AS TR ON
        DXE.EmpleadoId = TR.EmpleadoId AND DXE.TipoDeduccionId = TR.TipoDeduccionId;

        -- Eliminar la tabla temporal
        DROP TABLE #TempResult;
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0  -- error ocurrió dentro de la transacción
        BEGIN
            ROLLBACK TRANSACTION; -- deshacer los cambios realizados
        END;

        -- Manejo de errores: Puedes personalizar esto según tus necesidades
        SET @outResultCode = 50000; -- Código de resultado personalizado en caso de error

        INSERT INTO dbo.DBErrors VALUES (
            SUSER_SNAME(),
            ERROR_NUMBER(),
            ERROR_STATE(),
            ERROR_SEVERITY(),
            ERROR_LINE(),
            ERROR_PROCEDURE(),
            ERROR_MESSAGE(),
            GETDATE()
        );
    END CATCH

    SET NOCOUNT OFF;
END;
GO

-- %% [markdown]
-- # [dbo].[AcumularSalarioDeduccionesMensual]

-- %%
/****** Object:  StoredProcedure [dbo].[AcumularSalarioDeduccionesMensual]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[AcumularSalarioDeduccionesMensual]
    @outResultCode INT OUTPUT
AS
BEGIN
    -- SET NOCOUNT ON added to prevent extra result sets from interfering with SELECT statements.
    SET NOCOUNT ON;

    -- Inicializa el código de resultado a 0 (sin error)
    SET @outResultCode = 0;

    BEGIN TRY
        -- Actualizar el salario bruto mensual y el total de deducciones mensuales en la tabla PlanillaMexXEmpleado
        UPDATE [dbo].[PlanillaMexXEmpleado]
        SET SalarioBrutoMensual = ISNULL((
            SELECT SUM(PSE.SalarioBrutoSemanal)
            FROM [dbo].[PlanillaSemXEmpleado] AS PSE
            WHERE PSE.EmpleadoId = [dbo].[PlanillaMexXEmpleado].EmpleadoId
                AND DATEPART(MONTH, PSE.Fecha) = DATEPART(MONTH, GETDATE())
        ), 0),
        TotalDeduccionesMensual = ISNULL((
            SELECT SUM(DE.MontoDeduccion)
            FROM [dbo].[DeduccionesEmpleado] AS DE
            WHERE DE.EmpleadoId = [dbo].[PlanillaMexXEmpleado].EmpleadoId
                AND DATEPART(MONTH, DE.Fecha) = DATEPART(MONTH, GETDATE())
        ), 0);

    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0  -- error ocurrió dentro de la transacción
        BEGIN
            ROLLBACK TRANSACTION; -- deshacer los cambios realizados
        END;

        -- Manejo de errores: Puedes personalizar esto según tus necesidades
        SET @outResultCode = 50000; -- Código de resultado personalizado en caso de error

        INSERT INTO dbo.DBErrors VALUES (
            SUSER_SNAME(),
            ERROR_NUMBER(),
            ERROR_STATE(),
            ERROR_SEVERITY(),
            ERROR_LINE(),
            ERROR_PROCEDURE(),
            ERROR_MESSAGE(),
            GETDATE()
        );
    END CATCH

    SET NOCOUNT OFF;
END;
GO

-- %% [markdown]
-- # [dbo].[AcumularSalarioDeduccionesSemanal]

-- %%
/****** Object:  StoredProcedure [dbo].[AcumularSalarioDeduccionesSemanal]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AcumularSalarioDeduccionesSemanal]
    @outResultCode INT OUTPUT
AS
BEGIN
    -- SET NOCOUNT ON added to prevent extra result sets from interfering with SELECT statements.
    SET NOCOUNT ON;

    -- Inicializa el código de resultado a 0 (sin error)
    SET @outResultCode = 0;

    BEGIN TRY
        -- Inicia código en el cual se capturan errores

        -- Actualizar el salario bruto semanal y el total de deducciones semanales en la tabla PlanillaSemXEmpleado
        UPDATE PSE
        SET PSE.SalarioBrutoSemanal = ISNULL((
            SELECT SUM(Monto)
            FROM [dbo].[MovimientoPlanilla]
            WHERE EmpleadoId = PSE.EmpleadoId
                AND DATEPART(WEEK, fecha) = DATEPART(WEEK, GETDATE())
        ), 0),
        PSE.TotalDeduccionesSemanal = ISNULL((
            SELECT SUM(MontoDeduccion)
            FROM [dbo].[DeduccionesEmpleado]
            WHERE EmpleadoId = PSE.EmpleadoId
                AND DATEPART(WEEK, fecha) = DATEPART(WEEK, GETDATE())
        ), 0)
        FROM [dbo].[PlanillaSemXEmpleado] AS PSE;
    END TRY

    BEGIN CATCH
        IF @@TRANCOUNT > 0  -- error ocurrió dentro de la transacción
        BEGIN
            ROLLBACK TRANSACTION; -- deshacer los cambios realizados
        END;

        -- Manejo de errores: Puedes personalizar esto según tus necesidades
        SET @outResultCode = 50000; -- Código de resultado personalizado en caso de error

        INSERT INTO dbo.DBErrors VALUES (
            SUSER_SNAME(),
            ERROR_NUMBER(),
            ERROR_STATE(),
            ERROR_SEVERITY(),
            ERROR_LINE(),
            ERROR_PROCEDURE(),
            ERROR_MESSAGE(),
            GETDATE()
        );
    END CATCH

    SET NOCOUNT OFF;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertarMovimientoPorHoras]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertarMovimientoPorHoras]    Script Date: 20/10/2023 8:39:51 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertarMovimientoPorHoras]
	@inmarcasAsistenciaId INT,
	@inmonto MONEY,
	@innuevoSalarioBruto MONEY,
	@intipoMovPlanillaId INT,
	@outResultCode INT OUTPUT
AS
BEGIN

	SET NOCOUNT ON;

	BEGIN TRY


		INSERT INTO [dbo].[MovimientoPlanilla] (fecha, monto, nuevoSalarioBruto, tipoMovPlanillaId, movHorasId)
		VALUES (GETDATE(), @inmonto, @innuevoSalarioBruto, @intipoMovPlanillaId, NULL);


		DECLARE @inmovimientoId INT;
		SET @inmovimientoId = SCOPE_IDENTITY();

		INSERT INTO [dbo].[MovHoras] (marcasAsistenciaId)
		VALUES (@inmarcasAsistenciaId);

		UPDATE [dbo].[MovimientoPlanilla]
		SET movHorasId = @inmovimientoId
		WHERE id = @inmovimientoId;

	END TRY
	BEGIN CATCH
		IF @@TRANCOUNT > 0  
		BEGIN
			ROLLBACK TRANSACTION; 
		END;

		-- Manejo de errores: Puedes personalizar esto según tus necesidades
		SET @outResultCode = 50005;

		INSERT INTO dbo.DBErrors VALUES (
			SUSER_SNAME(),
			ERROR_NUMBER(),
			ERROR_STATE(),
			ERROR_SEVERITY(),
			ERROR_LINE(),
			ERROR_PROCEDURE(),
			ERROR_MESSAGE(),
			GETDATE()
		);
	END CATCH

	SET NOCOUNT OFF;
END;
GO

-- %% [markdown]
-- # [PlanillaObrera]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PlanillaObrera] SET  READ_WRITE 
GO
